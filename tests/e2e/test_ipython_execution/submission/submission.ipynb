# %% [markdown]
# # Huzzah a submission!

# %%
from autograder_platform.StudentSubmissionImpl.IPython.metadata import Cell, TestableCell
import matplotlib.pyplot as plt
Cell(id="imports")

# %%
TestableCell(id="generate_range", deps=[(0, "imports")])
def generateRange(x_low, x_high, y_low, y_high):
    return list(range(x_low, x_high)), list(range(y_low, y_high))

# %%
TestableCell(id="plot", deps=[(0, "imports"),(1, "generate_range")])
plt.plot(*generateRange(0,10,0,10))
plt.show()

# %% [markdown]
# Yeah, you can say that ive mastered this
